# %%
from pyson.utils import *
from pyson.common import *
from pyson.vision import *

# %%
paths = list(sorted(glob('checkpoints/facades_pix2pix/web/images/*')))
paths = paths[-15:]

for i in range(0, len(paths), 3):
    imgs = []
    print('-'*30)
    print(paths[i])
    for j in range(3):
        idx = i+j
        imgs.append(cv2.imread(paths[idx]))
    plot_images(imgs, dpi=300)
# Out:
# ------------------------------
# checkpoints/facades_pix2pix/web/images/epoch988_fake_B.png
# (1, 3)
# ------------------------------
# checkpoints/facades_pix2pix/web/images/epoch990_fake_B.png
# (1, 3)
# ------------------------------
# checkpoints/facades_pix2pix/web/images/epoch993_fake_B.png
# (1, 3)
# ------------------------------
# checkpoints/facades_pix2pix/web/images/epoch995_fake_B.png
# (1, 3)
# ------------------------------
# checkpoints/facades_pix2pix/web/images/epoch998_fake_B.png
# (1, 3)
